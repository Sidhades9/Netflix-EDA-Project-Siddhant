# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-82cb96f0-ebbc-4fc2-8220-40e39364872e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82cb96f0-ebbc-4fc2-8220-40e39364872e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('netflix_titles.csv')

# Drop ID column (not useful)
df.drop(columns=['show_id'], inplace=True)

# Clean 'date_added' safely
df['date_added'] = pd.to_datetime(df['date_added'].str.strip(), errors='coerce')

# Extract year
df['year_added'] = df['date_added'].dt.year

# %%
df.info()
df.isnull().sum()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   datetime64[ns]
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
#  11  year_added    8797 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(9)
# memory usage: 825.8+ KB
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# ...

# %%
sns.countplot(data=df, x='type', palette='Set2')
plt.title("Content Type on Netflix")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-6-2026737475.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='type', palette='Set2')

# %%
df['year_added'].value_counts().sort_index().plot(kind='bar', figsize=(12,6), color='salmon')
plt.title("Content Added Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.show()

# %%
genres = df['listed_in'].dropna().str.split(',').explode().str.strip()
genres.value_counts().head(10).plot(kind='barh', color='skyblue')
plt.title("Top 10 Most Common Genres")
plt.xlabel("Number of Titles")
plt.ylabel("Genre")
plt.gca().invert_yaxis()
plt.show()

# %%
df['country'].value_counts().head(10).plot(kind='bar', color='mediumseagreen')
plt.title("Top 10 Countries by Content")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(data=df, y='rating', order=df['rating'].value_counts().index, palette='muted')
plt.title("Content Rating Distribution")
plt.xlabel("Count")
plt.ylabel("Rating")
plt.show()
# Out:
# /tmp/ipython-input-10-2069497180.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='rating', order=df['rating'].value_counts().index, palette='muted')

# %% [markdown]
#  Summary of Insights – Netflix Data Analysis
# 📈 Netflix has steadily increased its content library, peaking in 2019–2020.
#
# 🎬 The majority of content is Movies, but TV Shows have grown consistently.
#
# 🌍 The United States produces the largest share of Netflix content.
#
# 🎭 Most common genres include Dramas, International Movies, and Comedies.
#
# 🔞 The platform heavily features mature ratings, especially TV-MA and TV-14 content.
#
# 📅 Using date_added, we were able to analyze year-wise trends and time-based patterns.
#
# ✅ Data was cleaned, formatted, and visualized using Python, Pandas, Seaborn, and Matplotlib.
